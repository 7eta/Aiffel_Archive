# %% [markdown]
# |평가문항|상세기준|
# |--|--|
# |1. U-Net을 통한 세그멘테이션 작업이 정상적으로 진행되었는가?|KITTI 데이터셋 구성, U-Net 모델 훈련, 결과물 시각화의 한 사이클이 정상 수행되어 세그멘테이션 결과 이미지를 제출하였다.|
# |2. U-Net++ 모델이 성공적으로 구현되었는가?|U-Net++ 모델을 스스로 구현하여 학습 진행 후 세그멘테이션 결과까지 정상 진행되었다.|
# |3. U-Net과 U-Net++ 두 모델의 성능이 정량적/정성적으로 잘 비교되었는가?|U-Net++ 의 세그멘테이션 결과 사진과 IoU 계산치를 U-Net과 비교하여 우월함을 확인하였다.|

# %%
import os
import math
import numpy as np
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob

# 다양한 Augmentation 기법을 활용하기 위한 'Albumentation 라이브러리'
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

# %% [markdown]
# ## KITTI 데이터셋 준비

# %%
dir_path = os.getenv('HOME')+'/aiffel/semantic_segmentation/data/training'

# %%
def build_augmentation(is_train=True):
    if is_train:    # 훈련용 데이터일 경우
        return Compose([
                        HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
                        RandomSizedCrop(         # 50%의 확률로 RandomSizedCrop
                            min_max_height=(300, 370),
                            w2h_ratio=370/1242,
                            height=224,
                            width=224,
                            p=0.5
                            ),
                        Resize(              # 입력이미지를 224X224로 resize
                            width=224,
                            height=224
                            )
                        ])
    return Compose([      # 테스트용 데이터일 경우에는 224X224로 resize만 수행합니다. 
                Resize(
                    width=224,
                    height=224
                    )
                ])

# %%
class KittiGenerator(tf.keras.utils.Sequence):
    '''
    KittiGenerator는 tf.keras.utils.Sequence를 상속받습니다.
    우리가 KittiDataset을 원하는 방식으로 preprocess하기 위해서 Sequnce를 커스텀해 사용합니다.
    '''
    def __init__(self, 
                 dir_path, 
                 batch_size=4, 
                 img_size=(224, 224, 3), 
                 output_size=(224, 224), 
                 is_train=True, 
                 augmentation=None):
        '''
        dir_path: dataset의 diLrectory path입니다.
        batch_size: batch_size입니다.
        img_size: preprocess에 사용할 입력이미지의 크기입니다.
        output_size: ground_truth를 만들어주기 위한 크기입니다.
        is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
        augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
        '''
        self.dir_path = dir_path
        self.batch_size = batch_size
        self.is_train = is_train
        self.dir_path = dir_path
        self.augmentation = augmentation
        self.img_size = img_size
        self.output_size = output_size

        # load_dataset()을 통해서 kitti dataset의 directory path에서 라벨과 이미지를 확인합니다.
        self.data = self.load_dataset()

    def load_dataset(self):
        # kitti dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수입니다.
        # 이때 is_train에 따라 test set을 분리해서 load하도록 해야합니다.
        input_images = glob(os.path.join(self.dir_path, "image_2", "*.png"))
        label_images = glob(os.path.join(self.dir_path, "semantic", "*.png"))
        input_images.sort()
        label_images.sort()
        assert len(input_images) == len(label_images)
        data = [ _ for _ in zip(input_images, label_images)]

        if self.is_train:
            return data[:-30]
        return data[-30:]
    
    def __len__(self):
        # Generator의 length로서 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 올림한 값을 반환합니다.
        return math.ceil(len(self.data) / self.batch_size)

    def __getitem__(self, index):
        # 입력과 출력을 만듭니다.
        # 입력은 resize및 augmentation이 적용된 input image이고 
        # 출력은 semantic label입니다.
        batch_data = self.data[
                               index*self.batch_size:
                               (index + 1)*self.batch_size
                               ]
        inputs = np.zeros([self.batch_size, *self.img_size])
        outputs = np.zeros([self.batch_size, *self.output_size])

        for i, data in enumerate(batch_data):
            input_img_path, output_path = data
            _input = imread(input_img_path)
            _output = imread(output_path)
            _output = (_output==7).astype(np.uint8)*1
            data = {
                  "image": _input,
                  "mask": _output,
                  }
            augmented = self.augmentation(**data)
            inputs[i] = augmented["image"]/255
            outputs[i] = augmented["mask"]
            return inputs, outputs

    def on_epoch_end(self):
    # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
        self.indexes = np.arange(len(self.data))
        if self.is_train == True :
            np.random.shuffle(self.indexes)
            return self.indexes

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
train_generator = KittiGenerator(
    dir_path, 
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %% [markdown]
# ## U-Net

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

# %%
def build_model(input_shape=(224, 224, 3)):
    inputs = Input(input_shape)

    #Contracting Path
    conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool4)  
    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv5)

    #Expanding Path
    drop5 = Dropout(0.5)(conv5)
    up6 = Conv2D(512, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(drop5)) 
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv6)
    up7 = Conv2D(256, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv7)
    up8 = Conv2D(128, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv8)
    up9 = Conv2D(64, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)  
    conv9 = Conv2D(2, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)     
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

    model = Model(inputs = inputs, outputs = conv10)
    
    return model

# %%
model_path = './my_seg_model_unet.h5'

model = build_model()
model.compile(optimizer = Adam(1e-4), loss = 'binary_crossentropy', metrics =['accuracy'])
unet_history = model.fit(
     train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

model.save(model_path)  #학습한 모델을 저장해 주세요.
# Out:
# Epoch 1/100
# 43/43 [==============================] - 21s 246ms/step - loss: 0.6933 - accuracy: 0.9184 - val_loss: 0.6913 - val_accuracy: 0.9362
# Epoch 2/100
# 43/43 [==============================] - 10s 239ms/step - loss: 0.7017 - accuracy: 0.9474 - val_loss: 0.6894 - val_accuracy: 0.9368
# Epoch 3/100
# 43/43 [==============================] - 10s 242ms/step - loss: 0.6884 - accuracy: 0.9439 - val_loss: 0.6873 - val_accuracy: 0.9377
# Epoch 4/100
# 43/43 [==============================] - 10s 242ms/step - loss: 0.6865 - accuracy: 0.9473 - val_loss: 0.6846 - val_accuracy: 0.9428
# Epoch 5/100
# 43/43 [==============================] - 10s 242ms/step - loss: 0.6843 - accuracy: 0.9485 - val_loss: 0.6832 - val_accuracy: 0.9418
# Epoch 6/100
# 43/43 [==============================] - 10s 244ms/step - loss: 0.6816 - accuracy: 0.9497 - val_loss: 0.6777 - val_accuracy: 0.9522
# Epoch 7/100
# 43/43 [==============================] - 11s 244ms/step - loss: 0.6774 - accuracy: 0.9595 - val_loss: 0.6790 - val_accuracy: 0.9404
# Epoch 8/100
# 43/43 [==============================] - 10s 244ms/step - loss: 0.6789 - accuracy: 0.9460 - val_loss: 0.6778 - val_accuracy: 0.9389
# Epoch 9/100
# 43/43 [==============================] - 11s 245ms/step - loss: 0.6740 - accuracy: 0.9530 - val_loss: 0.7279 - val_accuracy: 0.9257
# Epoch 10/100
# 43/43 [==============================] - 11s 246ms/step - loss: 0.6757 - accuracy: 0.9469 - val_loss: 0.6711 - val_accuracy: 0.9540
# Epoch 11/100
# 43/43 [==============================] - 11s 246ms/step - loss: 0.7212 - accuracy: 0.9300 - val_loss: 0.6706 - val_accuracy: 0.9477
# Epoch 12/100
# 43/43 [==============================] - 11s 246ms/step - loss: 0.6710 - accuracy: 0.9462 - val_loss: 0.6679 - val_accuracy: 0.9482
# Epoch 13/100
# 43/43 [==============================] - 11s 247ms/step - loss: 0.6636 - accuracy: 0.9661 - val_loss: 0.6655 - val_accuracy: 0.9513
# Epoch 14/100
# 43/43 [==============================] - 11s 248ms/step - loss: 0.6613 - accuracy: 0.9630 - val_loss: 0.6658 - val_accuracy: 0.9430
# Epoch 15/100
# 43/43 [==============================] - 11s 248ms/step - loss: 0.6560 - accuracy: 0.9691 - val_loss: 0.6509 - val_accuracy: 0.9758
# Epoch 16/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.6520 - accuracy: 0.9732 - val_loss: 0.6453 - val_accuracy: 0.9801
# Epoch 17/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.6492 - accuracy: 0.9709 - val_loss: 0.6439 - val_accuracy: 0.9760
# Epoch 18/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.6558 - accuracy: 0.9749 - val_loss: 0.6463 - val_accuracy: 0.9768
# Epoch 19/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.6489 - accuracy: 0.9778 - val_loss: 0.6403 - val_accuracy: 0.9811
# Epoch 20/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.6372 - accuracy: 0.9772 - val_loss: 0.6436 - val_accuracy: 0.9649
# Epoch 21/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.6434 - accuracy: 0.9729 - val_loss: 0.6487 - val_accuracy: 0.9527
# Epoch 22/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.6398 - accuracy: 0.9731 - val_loss: 0.6320 - val_accuracy: 0.9825
# Epoch 23/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.6359 - accuracy: 0.9792 - val_loss: 0.6313 - val_accuracy: 0.9783
# Epoch 24/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.6351 - accuracy: 0.9690 - val_loss: 0.6311 - val_accuracy: 0.9720
# Epoch 25/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6301 - accuracy: 0.9790 - val_loss: 0.6279 - val_accuracy: 0.9789
# Epoch 26/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.6369 - accuracy: 0.9684 - val_loss: 0.6266 - val_accuracy: 0.9770
# Epoch 27/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6299 - accuracy: 0.9747 - val_loss: 0.6368 - val_accuracy: 0.9519
# Epoch 28/100
# 43/43 [==============================] - 11s 252ms/step - loss: 0.6268 - accuracy: 0.9752 - val_loss: 0.6218 - val_accuracy: 0.9798
# Epoch 29/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6235 - accuracy: 0.9798 - val_loss: 0.6178 - val_accuracy: 0.9826
# Epoch 30/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6229 - accuracy: 0.9791 - val_loss: 0.6202 - val_accuracy: 0.9798
# Epoch 31/100
# 43/43 [==============================] - 11s 252ms/step - loss: 0.6223 - accuracy: 0.9792 - val_loss: 0.6229 - val_accuracy: 0.9713
# Epoch 32/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6218 - accuracy: 0.9773 - val_loss: 0.6132 - val_accuracy: 0.9833
# Epoch 33/100
# 43/43 [==============================] - 11s 252ms/step - loss: 0.6130 - accuracy: 0.9815 - val_loss: 0.6101 - val_accuracy: 0.9822
# Epoch 34/100
# 43/43 [==============================] - 11s 252ms/step - loss: 0.6135 - accuracy: 0.9808 - val_loss: 0.6057 - val_accuracy: 0.9838
# Epoch 35/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6104 - accuracy: 0.9827 - val_loss: 0.6044 - val_accuracy: 0.9828
# Epoch 36/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6129 - accuracy: 0.9813 - val_loss: 0.6036 - val_accuracy: 0.9843
# Epoch 37/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.6074 - accuracy: 0.9798 - val_loss: 0.6076 - val_accuracy: 0.9771
# Epoch 38/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6048 - accuracy: 0.9835 - val_loss: 0.5983 - val_accuracy: 0.9841
# Epoch 39/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6045 - accuracy: 0.9800 - val_loss: 0.6060 - val_accuracy: 0.9698
# Epoch 40/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6047 - accuracy: 0.9806 - val_loss: 0.6074 - val_accuracy: 0.9726
# Epoch 41/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6000 - accuracy: 0.9825 - val_loss: 0.5934 - val_accuracy: 0.9833
# Epoch 42/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6060 - accuracy: 0.9795 - val_loss: 0.5949 - val_accuracy: 0.9830
# Epoch 43/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.6046 - accuracy: 0.9807 - val_loss: 0.5929 - val_accuracy: 0.9828
# Epoch 44/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5984 - accuracy: 0.9796 - val_loss: 0.5915 - val_accuracy: 0.9838
# Epoch 45/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5938 - accuracy: 0.9825 - val_loss: 0.5900 - val_accuracy: 0.9778
# Epoch 46/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5936 - accuracy: 0.9787 - val_loss: 0.5872 - val_accuracy: 0.9843
# Epoch 47/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5919 - accuracy: 0.9800 - val_loss: 0.5877 - val_accuracy: 0.9801
# Epoch 48/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5873 - accuracy: 0.9846 - val_loss: 0.5839 - val_accuracy: 0.9793
# Epoch 49/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5867 - accuracy: 0.9824 - val_loss: 0.5828 - val_accuracy: 0.9812
# Epoch 50/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5935 - accuracy: 0.9744 - val_loss: 0.5794 - val_accuracy: 0.9842
# Epoch 51/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5837 - accuracy: 0.9813 - val_loss: 0.5760 - val_accuracy: 0.9839
# Epoch 52/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5817 - accuracy: 0.9805 - val_loss: 0.5793 - val_accuracy: 0.9813
# Epoch 53/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5801 - accuracy: 0.9819 - val_loss: 0.5727 - val_accuracy: 0.9853
# Epoch 54/100
# 43/43 [==============================] - 11s 252ms/step - loss: 0.5736 - accuracy: 0.9806 - val_loss: 0.5716 - val_accuracy: 0.9832
# Epoch 55/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5714 - accuracy: 0.9855 - val_loss: 0.5720 - val_accuracy: 0.9792
# Epoch 56/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5745 - accuracy: 0.9811 - val_loss: 0.5708 - val_accuracy: 0.9820
# Epoch 57/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5722 - accuracy: 0.9834 - val_loss: 0.5651 - val_accuracy: 0.9839
# Epoch 58/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5759 - accuracy: 0.9785 - val_loss: 0.5662 - val_accuracy: 0.9842
# Epoch 59/100
# 43/43 [==============================] - 11s 252ms/step - loss: 0.5686 - accuracy: 0.9806 - val_loss: 0.5781 - val_accuracy: 0.9649
# Epoch 60/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5681 - accuracy: 0.9827 - val_loss: 0.5664 - val_accuracy: 0.9797
# Epoch 61/100
# 43/43 [==============================] - 11s 247ms/step - loss: 0.5605 - accuracy: 0.9831 - val_loss: 0.5604 - val_accuracy: 0.9811
# Epoch 62/100
# 43/43 [==============================] - 11s 248ms/step - loss: 0.5644 - accuracy: 0.9837 - val_loss: 0.5586 - val_accuracy: 0.9828
# Epoch 63/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5601 - accuracy: 0.9814 - val_loss: 0.5565 - val_accuracy: 0.9826
# Epoch 64/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5630 - accuracy: 0.9806 - val_loss: 0.5614 - val_accuracy: 0.9794
# Epoch 65/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5583 - accuracy: 0.9844 - val_loss: 0.5518 - val_accuracy: 0.9844
# Epoch 66/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5564 - accuracy: 0.9813 - val_loss: 0.5478 - val_accuracy: 0.9850
# Epoch 67/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5495 - accuracy: 0.9859 - val_loss: 0.5464 - val_accuracy: 0.9833
# Epoch 68/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5608 - accuracy: 0.9787 - val_loss: 0.5485 - val_accuracy: 0.9842
# Epoch 69/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5422 - accuracy: 0.9866 - val_loss: 0.5460 - val_accuracy: 0.9813
# Epoch 70/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5507 - accuracy: 0.9820 - val_loss: 0.5509 - val_accuracy: 0.9749
# Epoch 71/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5469 - accuracy: 0.9824 - val_loss: 0.5409 - val_accuracy: 0.9830
# Epoch 72/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5413 - accuracy: 0.9848 - val_loss: 0.5390 - val_accuracy: 0.9829
# Epoch 73/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5494 - accuracy: 0.9822 - val_loss: 0.5688 - val_accuracy: 0.9410
# Epoch 74/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5676 - accuracy: 0.9453 - val_loss: 0.5699 - val_accuracy: 0.9355
# Epoch 75/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5681 - accuracy: 0.9391 - val_loss: 0.5685 - val_accuracy: 0.9355
# Epoch 76/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5662 - accuracy: 0.9409 - val_loss: 0.5672 - val_accuracy: 0.9355
# Epoch 77/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5645 - accuracy: 0.9418 - val_loss: 0.5658 - val_accuracy: 0.9355
# Epoch 78/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5643 - accuracy: 0.9381 - val_loss: 0.5644 - val_accuracy: 0.9355
# Epoch 79/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5620 - accuracy: 0.9410 - val_loss: 0.5631 - val_accuracy: 0.9355
# Epoch 80/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5614 - accuracy: 0.9384 - val_loss: 0.5617 - val_accuracy: 0.9355
# Epoch 81/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5606 - accuracy: 0.9367 - val_loss: 0.5603 - val_accuracy: 0.9355
# Epoch 82/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5574 - accuracy: 0.9422 - val_loss: 0.5590 - val_accuracy: 0.9355
# Epoch 83/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5558 - accuracy: 0.9427 - val_loss: 0.5576 - val_accuracy: 0.9355
# Epoch 84/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5539 - accuracy: 0.9443 - val_loss: 0.5562 - val_accuracy: 0.9355
# Epoch 85/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5549 - accuracy: 0.9375 - val_loss: 0.5548 - val_accuracy: 0.9355
# Epoch 86/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5491 - accuracy: 0.9500 - val_loss: 0.5534 - val_accuracy: 0.9356
# Epoch 87/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5520 - accuracy: 0.9377 - val_loss: 0.5521 - val_accuracy: 0.9356
# Epoch 88/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5482 - accuracy: 0.9444 - val_loss: 0.5504 - val_accuracy: 0.9363
# Epoch 89/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5467 - accuracy: 0.9444 - val_loss: 0.5456 - val_accuracy: 0.9438
# Epoch 90/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5413 - accuracy: 0.9564 - val_loss: 0.5479 - val_accuracy: 0.9357
# Epoch 91/100
# 43/43 [==============================] - 11s 248ms/step - loss: 0.5446 - accuracy: 0.9429 - val_loss: 0.5464 - val_accuracy: 0.9362
# Epoch 92/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5361 - accuracy: 0.9555 - val_loss: 0.5288 - val_accuracy: 0.9713
# Epoch 93/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5265 - accuracy: 0.9739 - val_loss: 0.5196 - val_accuracy: 0.9782
# Epoch 94/100
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5120 - accuracy: 0.9823 - val_loss: 0.5110 - val_accuracy: 0.9795
# Epoch 95/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5104 - accuracy: 0.9820 - val_loss: 0.5078 - val_accuracy: 0.9810
# Epoch 96/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5114 - accuracy: 0.9829 - val_loss: 0.5046 - val_accuracy: 0.9853
# Epoch 97/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5073 - accuracy: 0.9839 - val_loss: 0.5044 - val_accuracy: 0.9812
# Epoch 98/100
# 43/43 [==============================] - 11s 251ms/step - loss: 0.5118 - accuracy: 0.9799 - val_loss: 0.5026 - val_accuracy: 0.9838
# Epoch 99/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.4998 - accuracy: 0.9846 - val_loss: 0.5003 - val_accuracy: 0.9814
# Epoch 100/100
# 43/43 [==============================] - 11s 250ms/step - loss: 0.5051 - accuracy: 0.9834 - val_loss: 0.5032 - val_accuracy: 0.9813

# %% [markdown]
# ### 시각화

# %%
def calculate_iou_score(target, prediction):
    intersection = np.logical_and(target, prediction)
    union = np.logical_or(target, prediction)
    iou_score = float(np.sum(intersection)) / float(np.sum(union))
    print('IoU : %f' % iou_score )
    return iou_score

# %%
def get_output(model, preproc, image_path, output_path, label_path):
    origin_img = imread(image_path)
    data = {"image":origin_img}
    processed = preproc(**data)
    output = model(np.expand_dims(processed["image"]/255,axis=0))
    output = (output[0].numpy()>=0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
    prediction = output/255   # 도로로 판단한 영역
    
    output = Image.fromarray(output)
    background = Image.fromarray(origin_img).convert('RGBA')
    output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
    output = Image.blend(background, output, alpha=0.5)
    output.show()   # 도로로 판단한 영역을 시각화!
     
    if label_path:   
        label_img = imread(label_path)
        label_data = {"image":label_img}
        label_processed = preproc(**label_data)
        label_processed = label_processed["image"]
        target = (label_processed == 7).astype(np.uint8)*1   # 라벨에서 도로로 기재된 영역

        return output, prediction, target
    else:
        return output, prediction, _

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# <PIL.Image.Image image mode=RGBA size=1242x375 at 0x7FBC0814BF10>
# IoU : 0.903443
# 0.9034432234432235

# %% [markdown]
# ## U-Net++ 구현하기

# %% [markdown]
# ![](https://velog.velcdn.com/images/joonlaxy/post/2079b708-fa29-45a4-9fc4-39f8cf9cc2dc/image.png)

# %% [markdown]
# Resnet처럼 중간에 더 많은 SkipConnection이 추가됨을 볼 수 있었다.

# %%
import keras
import tensorflow as tf

from keras import backend as K
from keras.regularizers import l2
from keras.layers.noise import GaussianDropout

# %%
def standard_unit(input_tensor, stage, nb_filter, kernel_size=3):

    act = 'elu'
    dropout_rate = 0.5

    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(input_tensor)
#     x = Dropout(dropout_rate, name='dp'+stage+'_1')(x)
    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(x)
#     x = Dropout(dropout_rate, name='dp'+stage+'_2')(x)

    return x

# %%
# U-Net++ 구현
def Nest_Net(input_shape=(224, 224, 3), num_class=1, deep_supervision=False):
    nb_filter = [64,128,256,512,1024]
    
    img_input = Input(input_shape, name='main_input')
    
    # X_0,0
    conv1_1 = standard_unit(img_input, stage='11', nb_filter=nb_filter[0])
    pool1 = MaxPooling2D((2, 2), strides=(2, 2), name='pool1')(conv1_1)
    
    # X_1,0
    conv2_1 = standard_unit(pool1, stage='21', nb_filter=nb_filter[1])
    pool2 = MaxPooling2D((2, 2), strides=(2, 2), name='pool2')(conv2_1)
    
    # X_0,1
    # Upsampling
    up1_2 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up12', padding='same')(conv2_1)
    # Skip Connection
    conv1_2 = concatenate([up1_2, conv1_1], name='merge12', axis=3)
    conv1_2 = standard_unit(conv1_2, stage='12', nb_filter=nb_filter[0])
    
    # X_2,0
    conv3_1 = standard_unit(pool2, stage='31', nb_filter=nb_filter[2])
    pool3 = MaxPooling2D((2, 2), strides=(2, 2), name='pool3')(conv3_1)
    
    # X_1,1
    # Upsampling
    up2_2 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up22', padding='same')(conv3_1)
    # Skip Connection
    conv2_2 = concatenate([up2_2, conv2_1], name='merge22', axis=3)
    conv2_2 = standard_unit(conv2_2, stage='22', nb_filter=nb_filter[1])
    
    # X_0,2
    # Upsampling
    up1_3 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up13', padding='same')(conv2_2)
    # Skip Connection
    conv1_3 = concatenate([up1_3, conv1_1, conv1_2], name='merge13', axis=3)
    conv1_3 = standard_unit(conv1_3, stage='13', nb_filter=nb_filter[0])
    
    # X_3,0
    conv4_1 = standard_unit(pool3, stage='41', nb_filter=nb_filter[3])
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='pool4')(conv4_1)
    
    # X_2,1
    # Upsampling
    up3_2 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up32', padding='same')(conv4_1)
    # Skip Connection
    conv3_2 = concatenate([up3_2, conv3_1], name='merge32', axis=3)
    conv3_2 = standard_unit(conv3_2, stage='32', nb_filter=nb_filter[2])
    
    # X_1,2
    # Upsampling
    up2_3 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up23', padding='same')(conv3_2)
    # Skip Conncection
    conv2_3 = concatenate([up2_3, conv2_1, conv2_2], name='merge23', axis=3)
    conv2_3 = standard_unit(conv2_3, stage='23', nb_filter=nb_filter[1])
    
    # X_0,3
    # Upsampling
    up1_4 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up14', padding='same')(conv2_3)
    # Skip Connection
    conv1_4 = concatenate([up1_4, conv1_1, conv1_2, conv1_3], name='merge14', axis=3)
    conv1_4 = standard_unit(conv1_4, stage='14', nb_filter=nb_filter[0])
    
    # X_4,0
    conv5_1 = standard_unit(pool4, stage='51', nb_filter=nb_filter[4])
    ########
    # X_3,1
    # Upsampling
    up4_2 = Conv2DTranspose(nb_filter[3], (2, 2), strides=(2, 2), name='up42', padding='same')(conv5_1)
    # Skip Connection
    conv4_2 = concatenate([up4_2, conv4_1], name='merge42', axis=3)
    conv4_2 = standard_unit(conv4_2, stage='42', nb_filter=nb_filter[3])
    
    # X_2,2
    # Upsampling
    up3_3 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up33', padding='same')(conv4_2)
    # Skip Connection
    conv3_3 = concatenate([up3_3, conv3_1, conv3_2], name='merge33', axis=3)
    conv3_3 = standard_unit(conv3_3, stage='33', nb_filter=nb_filter[2])
    
    # X_1,3
    # Upsampling
    up2_4 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up24', padding='same')(conv3_3)
    # Skip Connection
    conv2_4 = concatenate([up2_4, conv2_1, conv2_2, conv2_3], name='merge24', axis=3)
    conv2_4 = standard_unit(conv2_4, stage='24', nb_filter=nb_filter[1])
    
    # X_0,4
    # Upsampling
    up1_5 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up15', padding='same')(conv2_4)
    # Skip Connection
    conv1_5 = concatenate([up1_5, conv1_1, conv1_2, conv1_3, conv1_4], name='merge15', axis=3)
    conv1_5 = standard_unit(conv1_5, stage='15', nb_filter=nb_filter[0])
    
    # output
    nesnet_output_1 = Conv2D(num_class, (1,1), activation='sigmoid', name='output_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_2)
    nesnet_output_2 = Conv2D(num_class, (1,1), activation='sigmoid', name='output_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_3)
    nesnet_output_3 = Conv2D(num_class, (1,1), activation='sigmoid', name='output_3', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_4)
    nesnet_output_4 = Conv2D(num_class, (1,1), activation='sigmoid', name='output_4', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_5)
    
    # Supervision 여부에 따른 출력 결정
    if deep_supervision:
        model = Model(inputs=img_input, outputs=[nesnet_output_1,
                                              nesnet_output_2,
                                              nesnet_output_3,
                                              nesnet_output_4])
    else:
        model = Model(inputs=img_input, outputs = [nesnet_output_4])
        
    return model

# %%
model = Nest_Net(input_shape=(224,224,3))
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv11_1 (Conv2D)               (None, 224, 224, 64) 1792        main_input[0][0]
# __________________________________________________________________________________________________
# conv11_2 (Conv2D)               (None, 224, 224, 64) 36928       conv11_1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 112, 112, 64) 0           conv11_2[0][0]
# __________________________________________________________________________________________________
# conv21_1 (Conv2D)               (None, 112, 112, 128 73856       pool1[0][0]
# __________________________________________________________________________________________________
# conv21_2 (Conv2D)               (None, 112, 112, 128 147584      conv21_1[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 56, 56, 128)  0           conv21_2[0][0]
# __________________________________________________________________________________________________
# conv31_1 (Conv2D)               (None, 56, 56, 256)  295168      pool2[0][0]
# __________________________________________________________________________________________________
# conv31_2 (Conv2D)               (None, 56, 56, 256)  590080      conv31_1[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 28, 28, 256)  0           conv31_2[0][0]
# __________________________________________________________________________________________________
# conv41_1 (Conv2D)               (None, 28, 28, 512)  1180160     pool3[0][0]
# __________________________________________________________________________________________________
# conv41_2 (Conv2D)               (None, 28, 28, 512)  2359808     conv41_1[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 14, 14, 512)  0           conv41_2[0][0]
# __________________________________________________________________________________________________
# conv51_1 (Conv2D)               (None, 14, 14, 1024) 4719616     pool4[0][0]
# __________________________________________________________________________________________________
# conv51_2 (Conv2D)               (None, 14, 14, 1024) 9438208     conv51_1[0][0]
# __________________________________________________________________________________________________
# up42 (Conv2DTranspose)          (None, 28, 28, 512)  2097664     conv51_2[0][0]
# __________________________________________________________________________________________________
# merge42 (Concatenate)           (None, 28, 28, 1024) 0           up42[0][0]
#                                                                  conv41_2[0][0]
# __________________________________________________________________________________________________
# up32 (Conv2DTranspose)          (None, 56, 56, 256)  524544      conv41_2[0][0]
# __________________________________________________________________________________________________
# conv42_1 (Conv2D)               (None, 28, 28, 512)  4719104     merge42[0][0]
# __________________________________________________________________________________________________
# merge32 (Concatenate)           (None, 56, 56, 512)  0           up32[0][0]
#                                                                  conv31_2[0][0]
# __________________________________________________________________________________________________
# up22 (Conv2DTranspose)          (None, 112, 112, 128 131200      conv31_2[0][0]
# __________________________________________________________________________________________________
# conv42_2 (Conv2D)               (None, 28, 28, 512)  2359808     conv42_1[0][0]
# __________________________________________________________________________________________________
# conv32_1 (Conv2D)               (None, 56, 56, 256)  1179904     merge32[0][0]
# __________________________________________________________________________________________________
# merge22 (Concatenate)           (None, 112, 112, 256 0           up22[0][0]
#                                                                  conv21_2[0][0]
# __________________________________________________________________________________________________
# up12 (Conv2DTranspose)          (None, 224, 224, 64) 32832       conv21_2[0][0]
# __________________________________________________________________________________________________
# up33 (Conv2DTranspose)          (None, 56, 56, 256)  524544      conv42_2[0][0]
# __________________________________________________________________________________________________
# conv32_2 (Conv2D)               (None, 56, 56, 256)  590080      conv32_1[0][0]
# __________________________________________________________________________________________________
# conv22_1 (Conv2D)               (None, 112, 112, 128 295040      merge22[0][0]
# __________________________________________________________________________________________________
# merge12 (Concatenate)           (None, 224, 224, 128 0           up12[0][0]
#                                                                  conv11_2[0][0]
# __________________________________________________________________________________________________
# merge33 (Concatenate)           (None, 56, 56, 768)  0           up33[0][0]
#                                                                  conv31_2[0][0]
#                                                                  conv32_2[0][0]
# __________________________________________________________________________________________________
# conv22_2 (Conv2D)               (None, 112, 112, 128 147584      conv22_1[0][0]
# __________________________________________________________________________________________________
# up23 (Conv2DTranspose)          (None, 112, 112, 128 131200      conv32_2[0][0]
# __________________________________________________________________________________________________
# conv12_1 (Conv2D)               (None, 224, 224, 64) 73792       merge12[0][0]
# __________________________________________________________________________________________________
# conv33_1 (Conv2D)               (None, 56, 56, 256)  1769728     merge33[0][0]
# __________________________________________________________________________________________________
# merge23 (Concatenate)           (None, 112, 112, 384 0           up23[0][0]
#                                                                  conv21_2[0][0]
#                                                                  conv22_2[0][0]
# __________________________________________________________________________________________________
# conv12_2 (Conv2D)               (None, 224, 224, 64) 36928       conv12_1[0][0]
# __________________________________________________________________________________________________
# up13 (Conv2DTranspose)          (None, 224, 224, 64) 32832       conv22_2[0][0]
# __________________________________________________________________________________________________
# conv33_2 (Conv2D)               (None, 56, 56, 256)  590080      conv33_1[0][0]
# __________________________________________________________________________________________________
# conv23_1 (Conv2D)               (None, 112, 112, 128 442496      merge23[0][0]
# __________________________________________________________________________________________________
# merge13 (Concatenate)           (None, 224, 224, 192 0           up13[0][0]
#                                                                  conv11_2[0][0]
#                                                                  conv12_2[0][0]
# __________________________________________________________________________________________________
# up24 (Conv2DTranspose)          (None, 112, 112, 128 131200      conv33_2[0][0]
# __________________________________________________________________________________________________
# conv23_2 (Conv2D)               (None, 112, 112, 128 147584      conv23_1[0][0]
# __________________________________________________________________________________________________
# conv13_1 (Conv2D)               (None, 224, 224, 64) 110656      merge13[0][0]
# __________________________________________________________________________________________________
# merge24 (Concatenate)           (None, 112, 112, 512 0           up24[0][0]
#                                                                  conv21_2[0][0]
#                                                                  conv22_2[0][0]
#                                                                  conv23_2[0][0]
# __________________________________________________________________________________________________
# conv13_2 (Conv2D)               (None, 224, 224, 64) 36928       conv13_1[0][0]
# __________________________________________________________________________________________________
# up14 (Conv2DTranspose)          (None, 224, 224, 64) 32832       conv23_2[0][0]
# __________________________________________________________________________________________________
# conv24_1 (Conv2D)               (None, 112, 112, 128 589952      merge24[0][0]
# __________________________________________________________________________________________________
# merge14 (Concatenate)           (None, 224, 224, 256 0           up14[0][0]
#                                                                  conv11_2[0][0]
#                                                                  conv12_2[0][0]
#                                                                  conv13_2[0][0]
# __________________________________________________________________________________________________
# conv24_2 (Conv2D)               (None, 112, 112, 128 147584      conv24_1[0][0]
# __________________________________________________________________________________________________
# conv14_1 (Conv2D)               (None, 224, 224, 64) 147520      merge14[0][0]
# __________________________________________________________________________________________________
# up15 (Conv2DTranspose)          (None, 224, 224, 64) 32832       conv24_2[0][0]
# __________________________________________________________________________________________________
# conv14_2 (Conv2D)               (None, 224, 224, 64) 36928       conv14_1[0][0]
# __________________________________________________________________________________________________
# merge15 (Concatenate)           (None, 224, 224, 320 0           up15[0][0]
#                                                                  conv11_2[0][0]
#                                                                  conv12_2[0][0]
#                                                                  conv13_2[0][0]
#                                                                  conv14_2[0][0]
# __________________________________________________________________________________________________
# conv15_1 (Conv2D)               (None, 224, 224, 64) 184384      merge15[0][0]
# __________________________________________________________________________________________________
# conv15_2 (Conv2D)               (None, 224, 224, 64) 36928       conv15_1[0][0]
# __________________________________________________________________________________________________
# output_4 (Conv2D)               (None, 224, 224, 1)  65          conv15_2[0][0]
# ==================================================================================================
# Total params: 36,157,953
# Trainable params: 36,157,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
upp_dir_path = os.getenv('HOME')+'/aiffel/semantic_segmentation/my_upp_seg_model_unet.h5'

model_u_plus = Nest_Net()
model_u_plus.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics =['accuracy'])
unet_pp_history= model_u_plus.fit(
     train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

model.save(upp_dir_path)  #학습한 모델을 저장해 주세요.
# Out:
# Epoch 1/100
# 43/43 [==============================] - 24s 481ms/step - loss: 1.6330 - accuracy: 0.9371 - val_loss: 1.4347 - val_accuracy: 0.9640
# Epoch 2/100
# 43/43 [==============================] - 20s 476ms/step - loss: 1.3938 - accuracy: 0.9511 - val_loss: 1.3152 - val_accuracy: 0.9465
# Epoch 3/100
# 43/43 [==============================] - 21s 482ms/step - loss: 1.2556 - accuracy: 0.9619 - val_loss: 1.1720 - val_accuracy: 0.9746
# Epoch 4/100
# 43/43 [==============================] - 21s 489ms/step - loss: 1.1501 - accuracy: 0.9676 - val_loss: 1.1093 - val_accuracy: 0.9677
# Epoch 5/100
# 43/43 [==============================] - 21s 495ms/step - loss: 1.0681 - accuracy: 0.9704 - val_loss: 1.0259 - val_accuracy: 0.9747
# Epoch 6/100
# 43/43 [==============================] - 21s 499ms/step - loss: 1.0040 - accuracy: 0.9724 - val_loss: 0.9746 - val_accuracy: 0.9695
# Epoch 7/100
# 43/43 [==============================] - 21s 499ms/step - loss: 0.9500 - accuracy: 0.9694 - val_loss: 0.9053 - val_accuracy: 0.9790
# Epoch 8/100
# 43/43 [==============================] - 22s 502ms/step - loss: 0.9019 - accuracy: 0.9723 - val_loss: 0.8629 - val_accuracy: 0.9821
# Epoch 9/100
# 43/43 [==============================] - 22s 505ms/step - loss: 0.8678 - accuracy: 0.9756 - val_loss: 0.8412 - val_accuracy: 0.9759
# Epoch 10/100
# 43/43 [==============================] - 22s 508ms/step - loss: 0.8216 - accuracy: 0.9784 - val_loss: 0.8123 - val_accuracy: 0.9771
# Epoch 11/100
# 43/43 [==============================] - 22s 509ms/step - loss: 0.7825 - accuracy: 0.9815 - val_loss: 0.7765 - val_accuracy: 0.9755
# Epoch 12/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.7591 - accuracy: 0.9794 - val_loss: 0.7435 - val_accuracy: 0.9796
# Epoch 13/100
# 43/43 [==============================] - 22s 513ms/step - loss: 0.7229 - accuracy: 0.9849 - val_loss: 0.7346 - val_accuracy: 0.9769
# Epoch 14/100
# 43/43 [==============================] - 22s 500ms/step - loss: 0.7121 - accuracy: 0.9793 - val_loss: 0.7020 - val_accuracy: 0.9767
# Epoch 15/100
# 43/43 [==============================] - 22s 504ms/step - loss: 0.6933 - accuracy: 0.9767 - val_loss: 0.6891 - val_accuracy: 0.9764
# Epoch 16/100
# 43/43 [==============================] - 22s 506ms/step - loss: 0.6846 - accuracy: 0.9768 - val_loss: 0.7301 - val_accuracy: 0.9554
# Epoch 17/100
# 43/43 [==============================] - 22s 509ms/step - loss: 0.6786 - accuracy: 0.9687 - val_loss: 0.6558 - val_accuracy: 0.9711
# Epoch 18/100
# 43/43 [==============================] - 22s 512ms/step - loss: 0.6503 - accuracy: 0.9716 - val_loss: 0.6357 - val_accuracy: 0.9747
# Epoch 19/100
# 43/43 [==============================] - 22s 513ms/step - loss: 0.6261 - accuracy: 0.9777 - val_loss: 0.6220 - val_accuracy: 0.9726
# Epoch 20/100
# 43/43 [==============================] - 22s 513ms/step - loss: 0.6106 - accuracy: 0.9758 - val_loss: 0.6407 - val_accuracy: 0.9598
# Epoch 21/100
# 43/43 [==============================] - 22s 513ms/step - loss: 0.5918 - accuracy: 0.9799 - val_loss: 0.6049 - val_accuracy: 0.9672
# Epoch 22/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.5734 - accuracy: 0.9813 - val_loss: 0.5878 - val_accuracy: 0.9720
# Epoch 23/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.5497 - accuracy: 0.9855 - val_loss: 0.5548 - val_accuracy: 0.9805
# Epoch 24/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.5570 - accuracy: 0.9768 - val_loss: 0.5617 - val_accuracy: 0.9757
# Epoch 25/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.5412 - accuracy: 0.9796 - val_loss: 0.5365 - val_accuracy: 0.9768
# Epoch 26/100
# 43/43 [==============================] - 22s 506ms/step - loss: 0.5158 - accuracy: 0.9853 - val_loss: 0.5210 - val_accuracy: 0.9798
# Epoch 27/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.5117 - accuracy: 0.9819 - val_loss: 0.5122 - val_accuracy: 0.9792
# Epoch 28/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.5077 - accuracy: 0.9788 - val_loss: 0.5147 - val_accuracy: 0.9767
# Epoch 29/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.5021 - accuracy: 0.9774 - val_loss: 0.4976 - val_accuracy: 0.9761
# Epoch 30/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.4884 - accuracy: 0.9800 - val_loss: 0.5386 - val_accuracy: 0.9637
# Epoch 31/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.4768 - accuracy: 0.9824 - val_loss: 0.4934 - val_accuracy: 0.9752
# Epoch 32/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.4654 - accuracy: 0.9817 - val_loss: 0.4703 - val_accuracy: 0.9779
# Epoch 33/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.4601 - accuracy: 0.9812 - val_loss: 0.4582 - val_accuracy: 0.9788
# Epoch 34/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.4906 - accuracy: 0.9654 - val_loss: 0.4601 - val_accuracy: 0.9782
# Epoch 35/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.4607 - accuracy: 0.9781 - val_loss: 0.4498 - val_accuracy: 0.9806
# Epoch 36/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.4391 - accuracy: 0.9807 - val_loss: 0.4442 - val_accuracy: 0.9789
# Epoch 37/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.4307 - accuracy: 0.9825 - val_loss: 0.4348 - val_accuracy: 0.9786
# Epoch 38/100
# 43/43 [==============================] - 22s 518ms/step - loss: 0.4243 - accuracy: 0.9831 - val_loss: 0.4313 - val_accuracy: 0.9764
# Epoch 39/100
# 43/43 [==============================] - 22s 509ms/step - loss: 0.4172 - accuracy: 0.9820 - val_loss: 0.4398 - val_accuracy: 0.9738
# Epoch 40/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.4529 - accuracy: 0.9672 - val_loss: 0.4176 - val_accuracy: 0.9784
# Epoch 41/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.4352 - accuracy: 0.9711 - val_loss: 0.4108 - val_accuracy: 0.9813
# Epoch 42/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3999 - accuracy: 0.9825 - val_loss: 0.3982 - val_accuracy: 0.9812
# Epoch 43/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3941 - accuracy: 0.9827 - val_loss: 0.3852 - val_accuracy: 0.9844
# Epoch 44/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3939 - accuracy: 0.9793 - val_loss: 0.3986 - val_accuracy: 0.9766
# Epoch 45/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3813 - accuracy: 0.9838 - val_loss: 0.3838 - val_accuracy: 0.9803
# Epoch 46/100
# 43/43 [==============================] - 22s 518ms/step - loss: 0.3799 - accuracy: 0.9811 - val_loss: 0.3720 - val_accuracy: 0.9845
# Epoch 47/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3693 - accuracy: 0.9845 - val_loss: 0.3685 - val_accuracy: 0.9832
# Epoch 48/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3651 - accuracy: 0.9844 - val_loss: 0.3648 - val_accuracy: 0.9832
# Epoch 49/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3585 - accuracy: 0.9854 - val_loss: 0.3829 - val_accuracy: 0.9761
# Epoch 50/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3532 - accuracy: 0.9845 - val_loss: 0.3669 - val_accuracy: 0.9796
# Epoch 51/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3519 - accuracy: 0.9837 - val_loss: 0.3569 - val_accuracy: 0.9796
# Epoch 52/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3441 - accuracy: 0.9854 - val_loss: 0.3519 - val_accuracy: 0.9825
# Epoch 53/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3467 - accuracy: 0.9834 - val_loss: 0.3540 - val_accuracy: 0.9799
# Epoch 54/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.3420 - accuracy: 0.9827 - val_loss: 0.3496 - val_accuracy: 0.9795
# Epoch 55/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.3361 - accuracy: 0.9811 - val_loss: 0.3885 - val_accuracy: 0.9578
# Epoch 56/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.3403 - accuracy: 0.9779 - val_loss: 0.3770 - val_accuracy: 0.9682
# Epoch 57/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.3339 - accuracy: 0.9814 - val_loss: 0.3372 - val_accuracy: 0.9778
# Epoch 58/100
# 43/43 [==============================] - 22s 509ms/step - loss: 0.3333 - accuracy: 0.9798 - val_loss: 0.3305 - val_accuracy: 0.9790
# Epoch 59/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.3207 - accuracy: 0.9831 - val_loss: 0.3349 - val_accuracy: 0.9763
# Epoch 60/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.3124 - accuracy: 0.9863 - val_loss: 0.3175 - val_accuracy: 0.9817
# Epoch 61/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.3067 - accuracy: 0.9854 - val_loss: 0.3184 - val_accuracy: 0.9803
# Epoch 62/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.3034 - accuracy: 0.9868 - val_loss: 0.3254 - val_accuracy: 0.9756
# Epoch 63/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.3117 - accuracy: 0.9826 - val_loss: 0.3271 - val_accuracy: 0.9727
# Epoch 64/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.2978 - accuracy: 0.9873 - val_loss: 0.2998 - val_accuracy: 0.9837
# Epoch 65/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.2996 - accuracy: 0.9838 - val_loss: 0.3012 - val_accuracy: 0.9808
# Epoch 66/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.2913 - accuracy: 0.9863 - val_loss: 0.3125 - val_accuracy: 0.9788
# Epoch 67/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.2932 - accuracy: 0.9836 - val_loss: 0.3116 - val_accuracy: 0.9755
# Epoch 68/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.2918 - accuracy: 0.9826 - val_loss: 0.3240 - val_accuracy: 0.9721
# Epoch 69/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.2835 - accuracy: 0.9850 - val_loss: 0.2816 - val_accuracy: 0.9840
# Epoch 70/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.2867 - accuracy: 0.9834 - val_loss: 0.2862 - val_accuracy: 0.9808
# Epoch 71/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.2941 - accuracy: 0.9772 - val_loss: 0.3411 - val_accuracy: 0.9559
# Epoch 72/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.2887 - accuracy: 0.9798 - val_loss: 0.2789 - val_accuracy: 0.9831
# Epoch 73/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.2707 - accuracy: 0.9863 - val_loss: 0.2903 - val_accuracy: 0.9779
# Epoch 74/100
# 43/43 [==============================] - 22s 512ms/step - loss: 0.2732 - accuracy: 0.9831 - val_loss: 0.2764 - val_accuracy: 0.9823
# Epoch 75/100
# 43/43 [==============================] - 22s 513ms/step - loss: 0.2697 - accuracy: 0.9829 - val_loss: 0.2718 - val_accuracy: 0.9806
# Epoch 76/100
# 43/43 [==============================] - 22s 509ms/step - loss: 0.2608 - accuracy: 0.9864 - val_loss: 0.2849 - val_accuracy: 0.9763
# Epoch 77/100
# 43/43 [==============================] - 22s 506ms/step - loss: 0.2727 - accuracy: 0.9819 - val_loss: 0.2645 - val_accuracy: 0.9835
# Epoch 78/100
# 43/43 [==============================] - 22s 504ms/step - loss: 0.2570 - accuracy: 0.9858 - val_loss: 0.2741 - val_accuracy: 0.9796
# Epoch 79/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.2605 - accuracy: 0.9825 - val_loss: 0.2834 - val_accuracy: 0.9724
# Epoch 80/100
# 43/43 [==============================] - 22s 510ms/step - loss: 0.2506 - accuracy: 0.9855 - val_loss: 0.2594 - val_accuracy: 0.9814
# Epoch 81/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.2494 - accuracy: 0.9860 - val_loss: 0.2729 - val_accuracy: 0.9786
# Epoch 82/100
# 43/43 [==============================] - 22s 518ms/step - loss: 0.2445 - accuracy: 0.9865 - val_loss: 0.2487 - val_accuracy: 0.9846
# Epoch 83/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.2472 - accuracy: 0.9846 - val_loss: 0.2710 - val_accuracy: 0.9770
# Epoch 84/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.2411 - accuracy: 0.9868 - val_loss: 0.2705 - val_accuracy: 0.9782
# Epoch 85/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.2427 - accuracy: 0.9849 - val_loss: 0.2629 - val_accuracy: 0.9727
# Epoch 86/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.2396 - accuracy: 0.9845 - val_loss: 0.2468 - val_accuracy: 0.9811
# Epoch 87/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.2408 - accuracy: 0.9848 - val_loss: 0.2329 - val_accuracy: 0.9854
# Epoch 88/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.2370 - accuracy: 0.9835 - val_loss: 0.2304 - val_accuracy: 0.9857
# Epoch 89/100
# 43/43 [==============================] - 22s 517ms/step - loss: 0.2432 - accuracy: 0.9797 - val_loss: 0.2308 - val_accuracy: 0.9841
# Epoch 90/100
# 43/43 [==============================] - 22s 502ms/step - loss: 0.2400 - accuracy: 0.9801 - val_loss: 0.2322 - val_accuracy: 0.9824
# Epoch 91/100
# 43/43 [==============================] - 22s 501ms/step - loss: 0.2567 - accuracy: 0.9753 - val_loss: 0.2320 - val_accuracy: 0.9856
# Epoch 92/100
# 43/43 [==============================] - 21s 498ms/step - loss: 0.2516 - accuracy: 0.9783 - val_loss: 0.2412 - val_accuracy: 0.9816
# Epoch 93/100
# 43/43 [==============================] - 22s 512ms/step - loss: 0.2318 - accuracy: 0.9842 - val_loss: 0.2381 - val_accuracy: 0.9800
# Epoch 94/100
# 43/43 [==============================] - 22s 513ms/step - loss: 0.2361 - accuracy: 0.9802 - val_loss: 0.2265 - val_accuracy: 0.9837
# Epoch 95/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.2258 - accuracy: 0.9828 - val_loss: 0.2251 - val_accuracy: 0.9830
# Epoch 96/100
# 43/43 [==============================] - 21s 500ms/step - loss: 0.2198 - accuracy: 0.9864 - val_loss: 0.2215 - val_accuracy: 0.9833
# Epoch 97/100
# 43/43 [==============================] - 22s 510ms/step - loss: 0.2222 - accuracy: 0.9834 - val_loss: 0.2152 - val_accuracy: 0.9854
# Epoch 98/100
# 43/43 [==============================] - 22s 512ms/step - loss: 0.2226 - accuracy: 0.9827 - val_loss: 0.2398 - val_accuracy: 0.9787
# Epoch 99/100
# 43/43 [==============================] - 22s 505ms/step - loss: 0.2151 - accuracy: 0.9855 - val_loss: 0.2432 - val_accuracy: 0.9770
# Epoch 100/100
# 43/43 [==============================] - 22s 509ms/step - loss: 0.2158 - accuracy: 0.9851 - val_loss: 0.2517 - val_accuracy: 0.9753
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model_u_plus, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# <PIL.Image.Image image mode=RGBA size=1242x375 at 0x7FBA6AE58610>
# IoU : 0.872796
# 0.8727962351619021

# %% [markdown]
# ### 비교하기

# %% [markdown]
# |100epoch|U-Net|U-Net++|
# |--|--|--|
# |Iou|__0.903443__|0.872796|
# |Loss|0.503198|__0.251739__|
#
# 동일한 epoch에서 Unet++의 Loss가 더 빠르게 떨어짐을 확인할 수 있었다.

# %%
plt.figure(figsize=(18, 5))

plt.subplot(1, 2, 1)
plt.plot(unet_history.history['val_loss'], marker='.', c='red')
plt.plot(unet_pp_history.history['val_loss'], marker='.', c='blue')

plt.title('Model validation loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['U-Net', 'U-Net++'], loc='upper left')
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(unet_history.history['val_accuracy'], marker='.', c='red')
plt.plot(unet_pp_history.history['val_accuracy'], marker='.', c='blue')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['U-Net', 'U-Net++'], loc='upper left')
plt.grid()

plt.show()

# %% [markdown]
# 회고 : 충분한 시간이 더 있었다면 U-Net의 Loss가 충분히 떨어졌을 때의 IoU값이 기대된다.
